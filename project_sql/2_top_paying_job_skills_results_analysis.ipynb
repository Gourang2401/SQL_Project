# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data2 = pd.read_csv(r"C:\Users\Sristi v\Downloads\SQL_Project\project_sql\2_top_paying_job_skills_results.csv")
data2
# Out:
#      job_id                 job_title                 job_location  \
# 0    954793       Data Architect 2023  Bengaluru, Karnataka, India
# 1    954793       Data Architect 2023  Bengaluru, Karnataka, India
# 2    954793       Data Architect 2023  Bengaluru, Karnataka, India
# 3    954793       Data Architect 2023  Bengaluru, Karnataka, India
# 4    954793       Data Architect 2023  Bengaluru, Karnataka, India
# ..      ...                       ...                          ...
# 66   601909  Process and Data Analyst  Bengaluru, Karnataka, India
# 67  1781493              Data Analyst   Chennai, Tamil Nadu, India
# 68  1781493              Data Analyst   Chennai, Tamil Nadu, India
# 69  1781493              Data Analyst   Chennai, Tamil Nadu, India
# 70  1781493              Data Analyst   Chennai, Tamil Nadu, India
#
#     salary_year_avg company_name      skills
# 0          165000.0  Bosch Group         sql
# 1          165000.0  Bosch Group      python
# ...

# %%
df = data2['skills'].value_counts()
df1 = df.head(10)

# %%
plt.figure(figsize=(15, 6))
plt.bar(df1.index, df1.values)
plt.title('Skill count of top 10 paying Data analyst jobs in India', fontweight = 'bold')
plt.xlabel('Skills',fontweight = 'bold')
plt.ylabel('Count',fontweight = 'bold')
plt.tight_layout()
plt.show()
